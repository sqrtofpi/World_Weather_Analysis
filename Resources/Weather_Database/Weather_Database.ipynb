# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 751

# %%
# Import dependencies
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | esperance
# Processing Record 2 of Set 1 | bonthe
# Processing Record 3 of Set 1 | gobabis
# Processing Record 4 of Set 1 | agadir
# Processing Record 5 of Set 1 | pedernales
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | zhigansk
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | tura
# Processing Record 11 of Set 1 | narsaq
# Processing Record 12 of Set 1 | price
# Processing Record 13 of Set 1 | naryan-mar
# Processing Record 14 of Set 1 | sitka
# Processing Record 15 of Set 1 | tessalit
# Processing Record 16 of Set 1 | vagur
# Processing Record 17 of Set 1 | khandyga
# Processing Record 18 of Set 1 | dingle
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | pevek
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | turtkul
# City not found. Skipping...
# Processing Record 23 of Set 1 | warrnambool
# Processing Record 24 of Set 1 | tokur
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | punta alta
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | los llanos de aridane
# Processing Record 30 of Set 1 | quibdo
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | pacific grove
# Processing Record 34 of Set 1 | saint-augustin
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | kosovska mitrovica
# Processing Record 38 of Set 1 | ushtobe
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | valga
# Processing Record 41 of Set 1 | saldanha
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | trincomalee
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | vanimo
# Processing Record 46 of Set 1 | fukue
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | valasska bystrice
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | chokwe
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | cherskiy
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | aksu
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | aksarka
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | chulman
# Processing Record 11 of Set 2 | dombas
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | matiri
# Processing Record 15 of Set 2 | qujing
# Processing Record 16 of Set 2 | ajdabiya
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | mehamn
# Processing Record 20 of Set 2 | kidal
# Processing Record 21 of Set 2 | solnechnyy
# Processing Record 22 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 2 | berdigestyakh
# Processing Record 24 of Set 2 | rocha
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | nemuro
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | tateyama
# Processing Record 30 of Set 2 | wajima
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | torbay
# Processing Record 33 of Set 2 | nouadhibou
# Processing Record 34 of Set 2 | namatanai
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | yumen
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | lumberton
# Processing Record 39 of Set 2 | broome
# Processing Record 40 of Set 2 | bayangol
# Processing Record 41 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 2 | warri
# Processing Record 43 of Set 2 | banjar
# Processing Record 44 of Set 2 | zyryanka
# Processing Record 45 of Set 2 | bubaque
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | comodoro rivadavia
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | kodinsk
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | sao joao da barra
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | jiwani
# Processing Record 5 of Set 3 | pochutla
# Processing Record 6 of Set 3 | ambilobe
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | kenai
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | sumenep
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | latina
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | mareeba
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 3 | aklavik
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | trelew
# Processing Record 21 of Set 3 | tukrah
# Processing Record 22 of Set 3 | saint george
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | egvekinot
# Processing Record 25 of Set 3 | huancavelica
# Processing Record 26 of Set 3 | cayenne
# Processing Record 27 of Set 3 | shenxian
# Processing Record 28 of Set 3 | dongning
# Processing Record 29 of Set 3 | omboue
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | santa cruz del sur
# Processing Record 33 of Set 3 | yulara
# Processing Record 34 of Set 3 | haines junction
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | sao filipe
# Processing Record 37 of Set 3 | lloydminster
# Processing Record 38 of Set 3 | ponta do sol
# Processing Record 39 of Set 3 | george town
# Processing Record 40 of Set 3 | portland
# Processing Record 41 of Set 3 | geraldton
# Processing Record 42 of Set 3 | port lincoln
# Processing Record 43 of Set 3 | tete
# Processing Record 44 of Set 3 | noumea
# Processing Record 45 of Set 3 | laguna
# Processing Record 46 of Set 3 | ginda
# Processing Record 47 of Set 3 | chandrapur
# Processing Record 48 of Set 3 | port hedland
# Processing Record 49 of Set 3 | goure
# Processing Record 50 of Set 3 | luderitz
# Processing Record 1 of Set 4 | calobre
# City not found. Skipping...
# Processing Record 2 of Set 4 | abu dhabi
# Processing Record 3 of Set 4 | saint anthony
# Processing Record 4 of Set 4 | patiya
# Processing Record 5 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | ossora
# Processing Record 7 of Set 4 | vaini
# Processing Record 8 of Set 4 | borogontsy
# Processing Record 9 of Set 4 | zhuanghe
# Processing Record 10 of Set 4 | ha giang
# Processing Record 11 of Set 4 | kibre mengist
# Processing Record 12 of Set 4 | lata
# Processing Record 13 of Set 4 | margate
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | faanui
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | nome
# Processing Record 18 of Set 4 | bluff
# Processing Record 19 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | mount gambier
# Processing Record 22 of Set 4 | oktyabrskoye
# Processing Record 23 of Set 4 | kurilsk
# Processing Record 24 of Set 4 | kavaratti
# Processing Record 25 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 26 of Set 4 | bathsheba
# Processing Record 27 of Set 4 | abu samrah
# Processing Record 28 of Set 4 | touros
# Processing Record 29 of Set 4 | codrington
# Processing Record 30 of Set 4 | staryy nadym
# Processing Record 31 of Set 4 | ferrol
# Processing Record 32 of Set 4 | conceicao do araguaia
# Processing Record 33 of Set 4 | dalby
# Processing Record 34 of Set 4 | kamennogorsk
# Processing Record 35 of Set 4 | qaanaaq
# Processing Record 36 of Set 4 | sarkand
# Processing Record 37 of Set 4 | alofi
# Processing Record 38 of Set 4 | baft
# Processing Record 39 of Set 4 | wanaka
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | college
# Processing Record 43 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 4 | capreol
# Processing Record 45 of Set 4 | kaya
# Processing Record 46 of Set 4 | leningradskiy
# Processing Record 47 of Set 4 | angoche
# Processing Record 48 of Set 4 | dhidhdhoo
# Processing Record 49 of Set 4 | portobelo
# Processing Record 50 of Set 4 | labytnangi
# Processing Record 1 of Set 5 | padang
# Processing Record 2 of Set 5 | del carmen
# Processing Record 3 of Set 5 | yerbogachen
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | tautira
# Processing Record 6 of Set 5 | clarence town
# Processing Record 7 of Set 5 | rio bonito
# Processing Record 8 of Set 5 | syracuse
# Processing Record 9 of Set 5 | keti bandar
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | port elizabeth
# Processing Record 12 of Set 5 | kiama
# Processing Record 13 of Set 5 | tahoua
# Processing Record 14 of Set 5 | gusau
# Processing Record 15 of Set 5 | taoudenni
# Processing Record 16 of Set 5 | thinadhoo
# Processing Record 17 of Set 5 | barbalha
# Processing Record 18 of Set 5 | makakilo city
# Processing Record 19 of Set 5 | neryungri
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | bonnyville
# Processing Record 22 of Set 5 | almaznyy
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | sudak
# Processing Record 25 of Set 5 | baker city
# Processing Record 26 of Set 5 | kallithea
# Processing Record 27 of Set 5 | lowestoft
# Processing Record 28 of Set 5 | coahuayana
# Processing Record 29 of Set 5 | lorengau
# Processing Record 30 of Set 5 | kumluca
# Processing Record 31 of Set 5 | hirara
# Processing Record 32 of Set 5 | beloha
# Processing Record 33 of Set 5 | praia
# Processing Record 34 of Set 5 | sola
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 5 | kampot
# Processing Record 38 of Set 5 | mercedes
# Processing Record 39 of Set 5 | byron bay
# Processing Record 40 of Set 5 | axim
# Processing Record 41 of Set 5 | richards bay
# Processing Record 42 of Set 5 | taungdwingyi
# Processing Record 43 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 5 | bezenchuk
# Processing Record 45 of Set 5 | ribeira grande
# Processing Record 46 of Set 5 | redlands
# Processing Record 47 of Set 5 | pisco
# Processing Record 48 of Set 5 | pokaran
# Processing Record 49 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 50 of Set 5 | tromso
# Processing Record 1 of Set 6 | bjornevatn
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | grand-santi
# Processing Record 4 of Set 6 | fortuna
# Processing Record 5 of Set 6 | obidos
# Processing Record 6 of Set 6 | mersing
# Processing Record 7 of Set 6 | micheweni
# Processing Record 8 of Set 6 | gat
# Processing Record 9 of Set 6 | meulaboh
# Processing Record 10 of Set 6 | kupang
# Processing Record 11 of Set 6 | yar-sale
# Processing Record 12 of Set 6 | nikolskoye
# Processing Record 13 of Set 6 | birjand
# Processing Record 14 of Set 6 | sabang
# Processing Record 15 of Set 6 | kavieng
# Processing Record 16 of Set 6 | mirosi
# Processing Record 17 of Set 6 | carnarvon
# Processing Record 18 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 6 | iskateley
# Processing Record 20 of Set 6 | waipawa
# Processing Record 21 of Set 6 | provideniya
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | rafraf
# Processing Record 24 of Set 6 | medianeira
# Processing Record 25 of Set 6 | aban
# Processing Record 26 of Set 6 | santa maria del oro
# Processing Record 27 of Set 6 | voskresenskoye
# Processing Record 28 of Set 6 | vinstra
# Processing Record 29 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 6 | concordia
# Processing Record 31 of Set 6 | luba
# Processing Record 32 of Set 6 | burns lake
# Processing Record 33 of Set 6 | swan river
# Processing Record 34 of Set 6 | rincon
# Processing Record 35 of Set 6 | fairbanks
# Processing Record 36 of Set 6 | annau
# Processing Record 37 of Set 6 | vilhena
# Processing Record 38 of Set 6 | kapit
# Processing Record 39 of Set 6 | ambon
# Processing Record 40 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 6 | frome
# Processing Record 42 of Set 6 | tabas
# Processing Record 43 of Set 6 | banepa
# Processing Record 44 of Set 6 | mandalgovi
# Processing Record 45 of Set 6 | matagami
# Processing Record 46 of Set 6 | ketchikan
# Processing Record 47 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 6 | handwara
# City not found. Skipping...
# Processing Record 49 of Set 6 | kruisfontein
# Processing Record 50 of Set 6 | sibolga
# Processing Record 1 of Set 7 | flinders
# Processing Record 2 of Set 7 | okhotsk
# Processing Record 3 of Set 7 | jumla
# Processing Record 4 of Set 7 | leamington
# Processing Record 5 of Set 7 | bundaberg
# Processing Record 6 of Set 7 | hue
# Processing Record 7 of Set 7 | viet tri
# Processing Record 8 of Set 7 | tawzar
# City not found. Skipping...
# Processing Record 9 of Set 7 | constitucion
# Processing Record 10 of Set 7 | graham
# Processing Record 11 of Set 7 | xai-xai
# Processing Record 12 of Set 7 | saint-pierre
# Processing Record 13 of Set 7 | itanagar
# Processing Record 14 of Set 7 | mackay
# Processing Record 15 of Set 7 | matamoros
# Processing Record 16 of Set 7 | labuhan
# Processing Record 17 of Set 7 | berlevag
# Processing Record 18 of Set 7 | ilula
# Processing Record 19 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 7 | asyut
# Processing Record 22 of Set 7 | myitkyina
# Processing Record 23 of Set 7 | jijiga
# Processing Record 24 of Set 7 | rosetta
# Processing Record 25 of Set 7 | saquarema
# Processing Record 26 of Set 7 | dunblane
# Processing Record 27 of Set 7 | kudahuvadhoo
# Processing Record 28 of Set 7 | hofn
# Processing Record 29 of Set 7 | teguise
# Processing Record 30 of Set 7 | maua
# Processing Record 31 of Set 7 | leopold
# Processing Record 32 of Set 7 | soyo
# Processing Record 33 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 34 of Set 7 | honiara
# Processing Record 35 of Set 7 | russell
# Processing Record 36 of Set 7 | maldonado
# Processing Record 37 of Set 7 | sibu
# Processing Record 38 of Set 7 | severomuysk
# Processing Record 39 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 7 | nuuk
# Processing Record 41 of Set 7 | dobrinka
# Processing Record 42 of Set 7 | guerrero negro
# Processing Record 43 of Set 7 | knoxville
# Processing Record 44 of Set 7 | biak
# Processing Record 45 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 7 | villamontes
# Processing Record 47 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 7 | new norfolk
# Processing Record 49 of Set 7 | camana
# Processing Record 50 of Set 7 | buala
# Processing Record 1 of Set 8 | iqaluit
# Processing Record 2 of Set 8 | nyurba
# Processing Record 3 of Set 8 | clyde river
# Processing Record 4 of Set 8 | marawi
# Processing Record 5 of Set 8 | ilulissat
# Processing Record 6 of Set 8 | kamenka
# Processing Record 7 of Set 8 | valdivia
# Processing Record 8 of Set 8 | karabuk
# Processing Record 9 of Set 8 | domoni
# Processing Record 10 of Set 8 | caravelas
# Processing Record 11 of Set 8 | havre-saint-pierre
# Processing Record 12 of Set 8 | elizabeth city
# Processing Record 13 of Set 8 | palana
# Processing Record 14 of Set 8 | tecoanapa
# Processing Record 15 of Set 8 | avera
# Processing Record 16 of Set 8 | qaqortoq
# Processing Record 17 of Set 8 | bengkulu
# Processing Record 18 of Set 8 | mar del plata
# Processing Record 19 of Set 8 | esmeraldas
# Processing Record 20 of Set 8 | bara
# Processing Record 21 of Set 8 | oranzherei
# Processing Record 22 of Set 8 | holsted
# Processing Record 23 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 24 of Set 8 | grand gaube
# Processing Record 25 of Set 8 | port macquarie
# Processing Record 26 of Set 8 | severo-kurilsk
# Processing Record 27 of Set 8 | baykit
# Processing Record 28 of Set 8 | najran
# Processing Record 29 of Set 8 | jawhar
# Processing Record 30 of Set 8 | abong mbang
# Processing Record 31 of Set 8 | houma
# Processing Record 32 of Set 8 | garfield heights
# Processing Record 33 of Set 8 | villeta
# Processing Record 34 of Set 8 | westport
# Processing Record 35 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 8 | peleduy
# Processing Record 37 of Set 8 | kloulklubed
# Processing Record 38 of Set 8 | balbalan
# Processing Record 39 of Set 8 | sura
# Processing Record 40 of Set 8 | dunedin
# Processing Record 41 of Set 8 | kuzovatovo
# Processing Record 42 of Set 8 | coquimbo
# Processing Record 43 of Set 8 | konstantinovka
# Processing Record 44 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 8 | souillac
# Processing Record 46 of Set 8 | ostrovnoy
# Processing Record 47 of Set 8 | talnakh
# Processing Record 48 of Set 8 | paita
# Processing Record 49 of Set 8 | maningrida
# Processing Record 50 of Set 8 | gravdal
# Processing Record 1 of Set 9 | huai yot
# Processing Record 2 of Set 9 | yerkoy
# Processing Record 3 of Set 9 | pangody
# Processing Record 4 of Set 9 | burnie
# Processing Record 5 of Set 9 | kutum
# Processing Record 6 of Set 9 | grindavik
# Processing Record 7 of Set 9 | ugoofaaru
# Processing Record 8 of Set 9 | carlsbad
# Processing Record 9 of Set 9 | cabra
# Processing Record 10 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 9 | nanga eboko
# Processing Record 12 of Set 9 | le port
# Processing Record 13 of Set 9 | carahue
# Processing Record 14 of Set 9 | inuvik
# Processing Record 15 of Set 9 | beitbridge
# Processing Record 16 of Set 9 | karratha
# Processing Record 17 of Set 9 | dongsheng
# Processing Record 18 of Set 9 | manzanillo
# Processing Record 19 of Set 9 | uvalde
# Processing Record 20 of Set 9 | lagoa
# Processing Record 21 of Set 9 | wolmaranstad
# City not found. Skipping...
# Processing Record 22 of Set 9 | hovd
# Processing Record 23 of Set 9 | high level
# Processing Record 24 of Set 9 | lompoc
# Processing Record 25 of Set 9 | sinnamary
# Processing Record 26 of Set 9 | kyaikkami
# Processing Record 27 of Set 9 | sabha
# Processing Record 28 of Set 9 | saint-joseph
# Processing Record 29 of Set 9 | lianzhou
# Processing Record 30 of Set 9 | isangel
# Processing Record 31 of Set 9 | ust-kan
# Processing Record 32 of Set 9 | barra do garcas
# Processing Record 33 of Set 9 | licheng
# Processing Record 34 of Set 9 | parit buntar
# Processing Record 35 of Set 9 | yeppoon
# Processing Record 36 of Set 9 | itacoatiara
# Processing Record 37 of Set 9 | imeni poliny osipenko
# Processing Record 38 of Set 9 | sakmara
# Processing Record 39 of Set 9 | lavrentiya
# Processing Record 40 of Set 9 | marystown
# Processing Record 41 of Set 9 | olafsvik
# Processing Record 42 of Set 9 | viedma
# Processing Record 43 of Set 9 | sharan
# Processing Record 44 of Set 9 | lakes entrance
# Processing Record 45 of Set 9 | felipe carrillo puerto
# Processing Record 46 of Set 9 | kulhudhuffushi
# Processing Record 47 of Set 9 | bullhead city
# Processing Record 48 of Set 9 | santa rosa de osos
# Processing Record 49 of Set 9 | cap-aux-meules
# Processing Record 50 of Set 9 | havelock
# Processing Record 1 of Set 10 | conde
# Processing Record 2 of Set 10 | san quintin
# Processing Record 3 of Set 10 | bud
# Processing Record 4 of Set 10 | ola
# Processing Record 5 of Set 10 | porbandar
# Processing Record 6 of Set 10 | hami
# Processing Record 7 of Set 10 | xining
# Processing Record 8 of Set 10 | rochester
# Processing Record 9 of Set 10 | puerto madryn
# Processing Record 10 of Set 10 | necochea
# Processing Record 11 of Set 10 | roald
# Processing Record 12 of Set 10 | kaniama
# Processing Record 13 of Set 10 | arlit
# Processing Record 14 of Set 10 | hambantota
# Processing Record 15 of Set 10 | nalut
# Processing Record 16 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 10 | auki
# Processing Record 18 of Set 10 | narrabri
# Processing Record 19 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 10 | pangnirtung
# Processing Record 21 of Set 10 | evensk
# Processing Record 22 of Set 10 | port blair
# Processing Record 23 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 10 | kenora
# Processing Record 25 of Set 10 | manica
# Processing Record 26 of Set 10 | acapulco
# Processing Record 27 of Set 10 | malakal
# Processing Record 28 of Set 10 | moyale
# Processing Record 29 of Set 10 | saint-leu
# Processing Record 30 of Set 10 | osa
# Processing Record 31 of Set 10 | espinosa
# Processing Record 32 of Set 10 | severnyy
# Processing Record 33 of Set 10 | itarema
# Processing Record 34 of Set 10 | lasa
# Processing Record 35 of Set 10 | san vicente
# Processing Record 36 of Set 10 | sarh
# Processing Record 37 of Set 10 | valparaiso
# Processing Record 38 of Set 10 | fayaoue
# Processing Record 39 of Set 10 | puerto del rosario
# Processing Record 40 of Set 10 | akdagmadeni
# Processing Record 41 of Set 10 | zhanakorgan
# Processing Record 42 of Set 10 | poum
# Processing Record 43 of Set 10 | alvinopolis
# Processing Record 44 of Set 10 | klaksvik
# Processing Record 45 of Set 10 | macamic
# Processing Record 46 of Set 10 | bayshore gardens
# Processing Record 47 of Set 10 | araouane
# Processing Record 48 of Set 10 | butembo
# Processing Record 49 of Set 10 | nerchinskiy zavod
# Processing Record 50 of Set 10 | atambua
# Processing Record 1 of Set 11 | maneadero
# Processing Record 2 of Set 11 | anadyr
# Processing Record 3 of Set 11 | kathmandu
# Processing Record 4 of Set 11 | pontian kecil
# Processing Record 5 of Set 11 | dicabisagan
# Processing Record 6 of Set 11 | victoria
# Processing Record 7 of Set 11 | sokoni
# Processing Record 8 of Set 11 | tuatapere
# Processing Record 9 of Set 11 | nabire
# Processing Record 10 of Set 11 | rorvik
# Processing Record 11 of Set 11 | edea
# Processing Record 12 of Set 11 | rodrigues alves
# Processing Record 13 of Set 11 | muros
# Processing Record 14 of Set 11 | port hardy
# Processing Record 15 of Set 11 | balakhta
# Processing Record 16 of Set 11 | ville-marie
# Processing Record 17 of Set 11 | la palma
# Processing Record 18 of Set 11 | vicente guerrero
# Processing Record 19 of Set 11 | kazachinskoye
# Processing Record 20 of Set 11 | rey bouba
# Processing Record 21 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 11 | nyeri
# Processing Record 23 of Set 11 | port lavaca
# Processing Record 24 of Set 11 | katsuura
# Processing Record 25 of Set 11 | bam
# Processing Record 26 of Set 11 | xaxim
# Processing Record 27 of Set 11 | impfondo
# Processing Record 28 of Set 11 | omsukchan
# Processing Record 29 of Set 11 | ngunguru
# Processing Record 30 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 11 | praia da vitoria
# Processing Record 32 of Set 11 | kuusamo
# Processing Record 33 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 34 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 11 | pahrump
# Processing Record 36 of Set 11 | constantine
# Processing Record 37 of Set 11 | hamilton
# Processing Record 38 of Set 11 | orlik
# Processing Record 39 of Set 11 | ahipara
# Processing Record 40 of Set 11 | virginia beach
# Processing Record 41 of Set 11 | hobyo
# Processing Record 42 of Set 11 | ribas do rio pardo
# Processing Record 43 of Set 11 | kontagora
# Processing Record 44 of Set 11 | bogashevo
# Processing Record 45 of Set 11 | igrim
# Processing Record 46 of Set 11 | fare
# Processing Record 47 of Set 11 | general pico
# Processing Record 48 of Set 11 | rudnaya pristan
# Processing Record 49 of Set 11 | alferrarede
# Processing Record 50 of Set 11 | la ronge
# Processing Record 1 of Set 12 | sarakhs
# Processing Record 2 of Set 12 | komsomolskiy
# Processing Record 3 of Set 12 | chissamba
# Processing Record 4 of Set 12 | ndele
# Processing Record 5 of Set 12 | yazd
# Processing Record 6 of Set 12 | sudogda
# Processing Record 7 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 12 | ngerengere
# Processing Record 9 of Set 12 | oranjemund
# Processing Record 10 of Set 12 | katete
# Processing Record 11 of Set 12 | riyaq
# City not found. Skipping...
# Processing Record 12 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 13 of Set 12 | maragogi
# Processing Record 14 of Set 12 | kadnikov
# Processing Record 15 of Set 12 | sobolevo
# Processing Record 16 of Set 12 | itaqui
# Processing Record 17 of Set 12 | kristinehamn
# Processing Record 18 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 12 | tual
# Processing Record 20 of Set 12 | ottumwa
# Processing Record 21 of Set 12 | tsiroanomandidy
# Processing Record 22 of Set 12 | ancud
# Processing Record 23 of Set 12 | shakhtinsk
# Processing Record 24 of Set 12 | marivan
# Processing Record 25 of Set 12 | dubovskoye
# Processing Record 26 of Set 12 | kilindoni
# Processing Record 27 of Set 12 | osecina
# Processing Record 28 of Set 12 | salalah
# Processing Record 29 of Set 12 | anchorage
# Processing Record 30 of Set 12 | rauma
# Processing Record 31 of Set 12 | kuji
# Processing Record 32 of Set 12 | bonavista
# Processing Record 33 of Set 12 | rosarito
# Processing Record 34 of Set 12 | bogande
# Processing Record 35 of Set 12 | deputatskiy
# Processing Record 36 of Set 12 | launceston
# Processing Record 37 of Set 12 | natal
# Processing Record 38 of Set 12 | sorland
# Processing Record 39 of Set 12 | colares
# Processing Record 40 of Set 12 | kailahun
# Processing Record 41 of Set 12 | hobe sound
# Processing Record 42 of Set 12 | finnsnes
# Processing Record 43 of Set 12 | ahuimanu
# Processing Record 44 of Set 12 | havre
# Processing Record 45 of Set 12 | sainte-maxime
# Processing Record 46 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 47 of Set 12 | blackwater
# Processing Record 48 of Set 12 | merauke
# Processing Record 49 of Set 12 | cascais
# Processing Record 50 of Set 12 | bay saint louis
# Processing Record 1 of Set 13 | vestmanna
# Processing Record 2 of Set 13 | kalabo
# Processing Record 3 of Set 13 | farafangana
# Processing Record 4 of Set 13 | dudinka
# Processing Record 5 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 6 of Set 13 | kysyl-syr
# Processing Record 7 of Set 13 | muisne
# Processing Record 8 of Set 13 | hualmay
# Processing Record 9 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 10 of Set 13 | sal rei
# Processing Record 11 of Set 13 | veracruz
# Processing Record 12 of Set 13 | darnah
# Processing Record 13 of Set 13 | bandarbeyla
# Processing Record 14 of Set 13 | rawson
# Processing Record 15 of Set 13 | tuy hoa
# Processing Record 16 of Set 13 | victor harbor
# Processing Record 17 of Set 13 | jiamusi
# Processing Record 18 of Set 13 | tigil
# Processing Record 19 of Set 13 | boliqueime
# Processing Record 20 of Set 13 | hvide sande
# Processing Record 21 of Set 13 | sosnogorsk
# Processing Record 22 of Set 13 | mpika
# Processing Record 23 of Set 13 | tevaitoa
# Processing Record 24 of Set 13 | indianola
# Processing Record 25 of Set 13 | aykhal
# Processing Record 26 of Set 13 | zheleznodorozhnyy
# Processing Record 27 of Set 13 | reo
# Processing Record 28 of Set 13 | sakakah
# Processing Record 29 of Set 13 | frutal
# Processing Record 30 of Set 13 | rinconada
# Processing Record 31 of Set 13 | kitimat
# Processing Record 32 of Set 13 | sungaipenuh
# Processing Record 33 of Set 13 | novo oriente
# Processing Record 34 of Set 13 | bereda
# Processing Record 35 of Set 13 | nizhniy odes
# Processing Record 36 of Set 13 | kolpashevo
# Processing Record 37 of Set 13 | lisakovsk
# Processing Record 38 of Set 13 | ceyranbatan
# Processing Record 39 of Set 13 | macenta
# Processing Record 40 of Set 13 | san policarpo
# Processing Record 41 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 13 | dwarka
# Processing Record 43 of Set 13 | agua dulce
# Processing Record 44 of Set 13 | doha
# Processing Record 45 of Set 13 | gazojak
# Processing Record 46 of Set 13 | ha tinh
# Processing Record 47 of Set 13 | selma
# Processing Record 48 of Set 13 | massakory
# Processing Record 49 of Set 13 | moffat
# Processing Record 50 of Set 13 | shitkino
# Processing Record 1 of Set 14 | adrar
# Processing Record 2 of Set 14 | lubango
# Processing Record 3 of Set 14 | kurumkan
# Processing Record 4 of Set 14 | svirstroy
# Processing Record 5 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 14 | nijar
# Processing Record 7 of Set 14 | kleck
# City not found. Skipping...
# Processing Record 8 of Set 14 | tiznit
# Processing Record 9 of Set 14 | pauini
# Processing Record 10 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 11 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 12 of Set 14 | polson
# Processing Record 13 of Set 14 | turkistan
# Processing Record 14 of Set 14 | clacton-on-sea
# Processing Record 15 of Set 14 | polunochnoye
# Processing Record 16 of Set 14 | bac lieu
# Processing Record 17 of Set 14 | antequera
# Processing Record 18 of Set 14 | carora
# Processing Record 19 of Set 14 | udachnyy
# Processing Record 20 of Set 14 | sosnovo-ozerskoye
# Processing Record 21 of Set 14 | parnarama
# Processing Record 22 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 14 | austin
# Processing Record 24 of Set 14 | vokhma
# Processing Record 25 of Set 14 | te anau
# Processing Record 26 of Set 14 | eyl
# Processing Record 27 of Set 14 | culipapa
# City not found. Skipping...
# Processing Record 28 of Set 14 | nizwa
# Processing Record 29 of Set 14 | livenka
# Processing Record 30 of Set 14 | erenhot
# Processing Record 31 of Set 14 | faya
# Processing Record 32 of Set 14 | sorong
# Processing Record 33 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 34 of Set 14 | brae
# Processing Record 35 of Set 14 | kushiro
# Processing Record 36 of Set 14 | mogadouro
# Processing Record 37 of Set 14 | humaita
# Processing Record 38 of Set 14 | santa vitoria do palmar
# Processing Record 39 of Set 14 | kon tum
# Processing Record 40 of Set 14 | raipur
# Processing Record 41 of Set 14 | birao
# Processing Record 42 of Set 14 | quatre cocos
# Processing Record 43 of Set 14 | mbanza-ngungu
# Processing Record 44 of Set 14 | vila
# Processing Record 45 of Set 14 | calvinia
# Processing Record 46 of Set 14 | belyy yar
# Processing Record 47 of Set 14 | vila velha
# Processing Record 48 of Set 14 | carauari
# Processing Record 49 of Set 14 | varkaus
# Processing Record 50 of Set 14 | marathon
# Processing Record 1 of Set 15 | kasempa
# Processing Record 2 of Set 15 | shingu
# Processing Record 3 of Set 15 | sol-iletsk
# Processing Record 4 of Set 15 | anamur
# Processing Record 5 of Set 15 | sisimiut
# Processing Record 6 of Set 15 | mackenzie
# Processing Record 7 of Set 15 | lincoln
# Processing Record 8 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 15 | karakol
# Processing Record 10 of Set 15 | dubovka
# Processing Record 11 of Set 15 | palauig
# Processing Record 12 of Set 15 | tawang
# Processing Record 13 of Set 15 | buin
# Processing Record 14 of Set 15 | morgan city
# Processing Record 15 of Set 15 | cockburn town
# Processing Record 16 of Set 15 | shirokiy
# Processing Record 17 of Set 15 | anori
# Processing Record 18 of Set 15 | mount isa
# Processing Record 19 of Set 15 | dubbo
# Processing Record 20 of Set 15 | chum phae
# Processing Record 21 of Set 15 | wewak
# Processing Record 22 of Set 15 | vidim
# Processing Record 23 of Set 15 | chernyshevsk
# Processing Record 24 of Set 15 | maumere
# Processing Record 25 of Set 15 | luganville
# Processing Record 26 of Set 15 | sinjar
# Processing Record 27 of Set 15 | smrzovka
# Processing Record 28 of Set 15 | vao
# Processing Record 29 of Set 15 | qeshm
# Processing Record 30 of Set 15 | kafue
# Processing Record 31 of Set 15 | shumskiy
# Processing Record 32 of Set 15 | inongo
# Processing Record 33 of Set 15 | arman
# Processing Record 34 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing Record 35 of Set 15 | villa maria
# Processing Record 36 of Set 15 | southbridge
# Processing Record 37 of Set 15 | vrangel
# Processing Record 38 of Set 15 | deming
# Processing Record 39 of Set 15 | megion
# Processing Record 40 of Set 15 | awbari
# Processing Record 41 of Set 15 | lipari
# Processing Record 42 of Set 15 | ilinskiy
# Processing Record 43 of Set 15 | voloshka
# Processing Record 44 of Set 15 | mbinga
# Processing Record 45 of Set 15 | ranong
# Processing Record 46 of Set 15 | olovyannaya
# Processing Record 47 of Set 15 | donskoye
# Processing Record 48 of Set 15 | pyapon
# Processing Record 49 of Set 15 | husavik
# Processing Record 50 of Set 15 | kirtipur
# Processing Record 1 of Set 16 | bhadrachalam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Esperance      AU -33.8667  121.9000     60.13        44          37
# 1        Bonthe      SL   7.5264  -12.5050     81.12        76          96
# 2       Gobabis      NA -22.4500   18.9667     63.63        21           0
# 3        Agadir      MA  30.4202   -9.5982     79.25        52          12
# 4    Pedernales      DO  18.0384  -71.7440     87.62        57          79
# 5       Ushuaia      AR -54.8000  -68.3000     47.86        53           0
# 6      Zhigansk      RU  66.7697  123.3711     61.23        82         100
# 7         Tiksi      RU  71.6872  128.8694     34.18        87          99
# 8  Puerto Ayora      EC  -0.7393  -90.3518     80.56        87          63
# 9          Tura      IN  25.5198   90.2201     74.41        95          79
#
#    Wind Speed   Current Description
# 0       22.88            light rain
# 1        9.42            light rain
# 2       10.92             clear sky
# 3        6.64            few clouds
# 4        5.77         broken clouds
# 5        9.22             clear sky
# 6        9.22         moderate rain
# 7        7.65       overcast clouds
# 8        5.99         broken clouds
# 9        4.92  heavy intensity rain

# %%
output_data_file = "/Users/scottmacdonald/Desktop/UCB Data Bootcamp/Module 6 - WeatherPy with Python APIs/World_Weather_Analysis/Resources/Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
